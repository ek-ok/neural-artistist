# %%
# !ls ./data
# Out:
# NYC_night.jpg	 SG_night.jpg	      somposition.jpg	the_great_wave.jpg
# scream.jpg	 shanghai_pudong.jpg  source.txt	tubingen_van_gogh.jpg
# seated_nude.jpg  shipwreck.jpg	      starry_night.jpg	vgg19.npy

# %%
# %load_ext autoreload
# %autoreload 2

import get_image
import numpy as np

image_path = "data/"
vgg_params_path = "data/vgg19.npy"
content_image = "tubingen_van_gogh.jpg"
style_image = "starry_night.jpg"
# style_image = "the_great_wave.jpg"
iterations = 1000
alpha_beta_ratio = 1
# final_image = get_image.get_image(image_path, content_image, style_image, vgg_params_path, iterations)
final_image = get_image.get_image(image_path, content_image, style_image, vgg_params_path, iterations, alpha_beta_ratio)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# beta = Tensor("Cast_369:0", shape=(), dtype=float64), alpha = Tensor("Cast_370:0", shape=(), dtype=float64)
# VGG19 pre-trained params loaded
# VGG19 pre-trained params loaded
# VGG19 pre-trained params loaded
# input_image.shape (1, 900, 1200, 3)
# start building model
# model finished building; time taken = 0.16383028030395508
# input_image.shape (1, 900, 1200, 3)
# start building model
# model finished building; time taken = 0.1582186222076416
# input_image.shape (1, 285, 360, 3)
# start building model
# model finished building; time taken = 0.16029620170593262
# N type <class 'tensorflow.python.framework.tensor_shape.Dimension'>
# N type <class 'tensorflow.python.framework.ops.Tensor'>
# inside style loss fn
# N type <class 'tensorflow.python.framework.tensor_shape.Dimension'>
# N type <class 'tensorflow.python.framework.ops.Tensor'>
# inside style loss fn
# ...

# %%
final_image.shape
# Out:
# (1, 900, 1200, 3)

# %%
final_image
# Out:
# array([[[[  22.77578  ,   26.564116 ,   42.189068 ],
#          [ -39.670456 ,   -2.2712986,  -23.991348 ],
#          [  38.822075 ,  -14.784341 ,    8.461708 ],
#          ...,
#          [  57.515526 ,   39.07534  ,   12.149494 ],
#          [-102.60922  ,  -64.2844   ,   17.437538 ],
#          [   4.523516 ,   11.193879 , -178.3157   ]],
#
#         [[-118.378784 ,  -52.9337   ,  -44.259243 ],
#          [  53.836643 ,   30.85803  ,    2.449961 ],
#          [ -36.719482 ,    8.791911 ,  -78.223976 ],
#          ...,
#          [  29.566309 ,  -81.991486 , -126.78096  ],
#          [ -26.735714 ,   30.94672  ,   35.75937  ],
#          [ -54.029385 ,  -60.381516 ,   66.12896  ]],
#
#         [[  71.40988  ,  -82.73489  ,   -9.4612875],
#          [-138.58481  , -105.1523   ,   52.369614 ],
#          [  -0.9239391,   27.979635 ,    9.829533 ],
#          ...,
#          [ 101.70093  ,    2.7392335,  -43.106556 ],
#          [-112.78754  ,   18.438026 ,   65.69979  ],
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(final_image[0]);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# bgr
vgg_mean = [103.939, 116.779, 123.68]

# %%
final_image1 = final_image[0].copy()

# %%
final_image1[:, :, 0] += vgg_mean[2]
final_image1[:, :, 1] += vgg_mean[1]
final_image1[:, :, 2] += vgg_mean[0]

# %%
final_image1 = final_image1.astype(int)

plt.imshow(final_image1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
final_image1

# %%
2**64
# Out:
# 18446744073709551616
