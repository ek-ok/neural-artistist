# %%
# %load_ext autoreload
# %autoreload 2

import get_image
import numpy as np

image_path = "./neural-artistist/data/"
vgg_params_path = "./vgg19.npy"
content_image = "shanghai_pudong.jpg"
style_image = "the_great_wave.jpg"
iterations = 100

final_image = get_image.get_image(image_path, content_image, style_image, vgg_params_path, iterations)
# Out:
# /anaconda3/envs/dlenv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# VGG19 pre-trained params loaded
# VGG19 pre-trained params loaded
# VGG19 pre-trained params loaded
# start building model
# input_image.shape (1, 1050, 2100, 3)
# model finished building; time taken = 0.3453547954559326
# start building model
# input_image.shape (1, 1050, 2100, 3)
# model finished building; time taken = 0.38843798637390137
# start building model
# input_image.shape (1, 1721, 2560, 3)
# model finished building; time taken = 0.6715388298034668
# content_loss= Tensor("L2Loss:0", shape=(), dtype=float32)
# conv5_2_style_op.shape= (17280, 512)
# style_loss.dtype <dtype: 'float32'>
# style_loss= Tensor("mul_1:0", shape=(), dtype=float32)
# ...

# %%
final_image.shape
# Out:
# (1, 1050, 2100, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(final_image[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
final_image_flat = final_image.flatten()

# %%
from PIL import Image
content_image1 = np.array(Image.open(image_path + content_image), dtype='float32')

# %%
image_shape = content_image1.shape
image_num_pixels = np.array(image_shape)
image_num_pixels = image_num_pixels[0] * image_num_pixels[1] * image_num_pixels[2]
image = np.random.ranf(image_num_pixels)
image = image.reshape(image_shape)

# %%
plt.imshow(image)

# %%
5e-3
# Out:
# 0.005
